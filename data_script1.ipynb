# %% [markdown]
# # Economy/PremiumEconomy

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
        #everywhere
        web2=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span')
        click1=web2.click()
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        return web
    def name(self):
        for x in range(3):
            driver.execute_script("window.scrollTo(0,100000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# INFO:WDM:Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# INFO:WDM:Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, booking date

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
        #everywhere
        web2=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span')
        click1=web2.click()
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[1]').click()
        return web
    def name(self):
        for x in range(7):
            driver.execute_script("window.scrollTo(0,100000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-26-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_41.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ****************************** Establishing Connection ******************************
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 27th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[3]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-27-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_3.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 28th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[4]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-28-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_4.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 29th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[5]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-29-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_5.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 30th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[6]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-30-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_6.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 1st

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[7]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-01-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_7.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 2nd

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[8]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-02-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_8.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 3rd

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[9]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-03-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_9.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 4th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[10]').click()
        return web
    def name(self):
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-04-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_10.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 5th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[11]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-05-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_11.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 6th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[12]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-06-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_12.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 7th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[13]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-07-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_13.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 8th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[14]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-08-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_14.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 9th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[15]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-09-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_15.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 10th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[16]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-10-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_16.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 12th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[18]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-12-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_18.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 13th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[19]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-13-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_19.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 14th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[20]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-14-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_20.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 15th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[21]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-15-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_21.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 16th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[22]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-16-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_22.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 17th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[23]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-17-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_23.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 18th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[24]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-18-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_24.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 19th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[25]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-19-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_25.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 20th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[26]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-20-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_26.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 21st

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[27]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-21-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_27.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 22nd

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[28]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-22-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_28.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 23rd

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[29]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-23-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_29.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 24th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[30]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-24-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_30.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 25th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[31]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-25-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_31.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40
# Out:
# 1199

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40]

# %%
len(lst)
# Out:
# 32

# %% [markdown]
# # Economy/PremiumEconomy, depart 26th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(3):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[32]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_32.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39
# Out:
# 1238

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39]

# %%
len(lst)
# Out:
# 33

# %% [markdown]
# # Economy/PremiumEconomy, depart 27th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[33]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-27-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_33.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40
# Out:
# 1278

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40]

# %%
len(lst)
# Out:
# 34

# %% [markdown]
# # Economy/PremiumEconomy, depart 28th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[34]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-28-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_34.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40+40
# Out:
# 1318

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40,40]

# %%
len(lst)
# Out:
# 35

# %% [markdown]
# # Economy/PremiumEconomy, depart 29th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[35]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-29-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_35.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40+40+40
# Out:
# 1358

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40,40,40]

# %%
len(lst)
# Out:
# 36

# %% [markdown]
# # Economy/PremiumEconomy, depart 30th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[36]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-30-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_36.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40+40+40+40
# Out:
# 1398

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40,40,40,40]

# %%
len(lst)
# Out:
# 37

# %% [markdown]
# # Economy/PremiumEconomy, depart 31st

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[37]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-31-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_37.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40+40+40+40+41
# Out:
# 1439

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40,40,40,40,41]

# %%
len(lst)
# Out:
# 38

# %% [markdown]
# # Economy/PremiumEconomy, depart 1st

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(4):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[38]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('08-01-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_38.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
44+9+15+43+34+40+35+37+39+41+40+37+39+38+41+39+43+40+38+38+39+41+39+39+39+39+39+38+38+38+40+40+39+40+40+40+40+41+40
# Out:
# 1479

# %%
lst=[44,9,15,43,34,40,35,37,39,41,40,37,39,38,41,39,43,40,38,38,39,41,39,39,39,39,39,38,38,38,40,40,39,40,40,40,40,41,40]

# %%
len(lst)
# Out:
# 39

# %% [markdown]
# # PremiumEconomy, depart 26th, double seat

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web111=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/label/span')
        click111=web111.click()
        web112=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[1]/ul[2]/li[2]')
        click112=web112.click()   
        web114=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[2]/button')
        click114=web114.click()           
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
#        for x in range(4):        
#            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/header/div[2]/div/ul/li[5]/span[2]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Premium Economy')
            self.fare_type.append('Double Seater')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_39.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Business, depart 26th, double seat

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web111=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/label/span')
        click111=web111.click()
        web112=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[1]/ul[2]/li[3]')
        click112=web112.click()   
        web114=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[2]/button')
        click114=web114.click()           
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
#        for x in range(4):        
#            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/header/div[2]/div/ul/li[5]/span[2]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Business')
            self.fare_type.append('Double Seater')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_40.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy, depart 11th

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from datetime import date, timedelta

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
        today = date.today()
        from_date = today + timedelta(days=1)
        to_date = today + timedelta(days=10)
        self.from_date=from_date
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue   
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
#        web222=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[3]/label/span').click()
#        for x in range(3):        
#            self.driver.execute_script("window.scrollTo(0,100)")
        #<div class="DayPicker-Day" tabindex="-1" role="gridcell" aria-label="Mon Jun 27 2022" aria-disabled="false" aria-selected="false"><div class="dateInnerCell"><p>27</p><p class=" todayPrice">9416</p></div></div>    
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        for x in range(2):        
            web204=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/button[2]').click()
        web224=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div[17]').click()
        return web
    def name(self):
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue        
        for x in range(7):
            self.driver.execute_script("window.scrollTo(0,10000000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('07-11-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_17.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Economy/PremiumEconomy

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
 #       web1=self.driver.find_element_by_xpath('/html/body/div[2]/main/div[1]/div/div/div[1]/div/div/div/div/div/form/div[1]/div/label[1]/div') #return
 #       click=web1.click()#click on cars
        #everywhere
        web2=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span')
        click1=web2.click()
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        return web
    def name(self):
        for x in range(3):
            driver.execute_script("window.scrollTo(0,100000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# INFO:WDM:Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# INFO:WDM:Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %% [markdown]
# # Premium Economy

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue
        #round trip
        web1=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/label') #round trip
        click=web1.click()#click on round trip
        web111=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[1]/ul[2]/li[2]')
        click111=web111.click()
        web112=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[2]/button')
        click112=web112.click()
 #       #everywhere
 #       web2=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span')
 #       click1=web2.click()
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        return web
    def name(self):
        for x in range(3):
            driver.execute_script("window.scrollTo(0,100000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Premium Economy')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_1.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    flights1=sel.duration_()
    flights2=sel.static_data()
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************

# %% [markdown]
# # Business

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import SessionNotCreatedException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
class selenium_scrape:
    def __init__(self,driver,url,trip_type, from_, to, return_, passenger, class_, fare_type, flight,flight_id,
                 stops, journey_type, duration, depart_time, arrival_time, booking_date, depart_date,fare):
        self.driver=driver
        self.url=url
        self.trip_type=trip_type
        self.from_=from_
        self.to=to
        self.return_=return_
        self.passenger=passenger
        self.class_=class_
        self.fare_type=fare_type
        self.flight=flight
        self.flight_id=flight_id
        self.stops=stops
        self.journey_type=journey_type
        self.duration=duration
        self.depart_time=depart_time
        self.arrival_time=arrival_time
        self.booking_date=booking_date
        self.depart_date=depart_date
        self.fare=fare
    def connection(self):
        self.driver.maximize_window()
        time.sleep(3)
        return self.driver
    def web_search(self):
        web=self.driver.get(self.url)
        for x in range(1):
            try:
                lang_card=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span').click()
            except NoSuchElementException:
                continue
        #round trip
        web1=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/label') #round trip
        click=web1.click()#click on round trip
        web111=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[1]/ul[2]/li[3]')
        click111=web111.click()
        web112=self.driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[5]/div[2]/div[2]/button')
        click112=web112.click()
 #       #everywhere
 #       web2=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/main/div[9]/span')
 #       click1=web2.click()
        #submit button
        web3=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
        click2=web3.click()
        time.sleep(3)
        for x in range(1):
            try:
                web4=self.driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div/div/div[3]/button')
                click3=web4.click()
                time.sleep(3)
            except NoSuchElementException:
                continue
        return web
    def name(self):
        for x in range(3):
            driver.execute_script("window.scrollTo(0,100000)")
            time.sleep(3)
                # <p class="boldFont blackText airlineName">AirAsia</p>
        new_web=self.driver.find_elements_by_xpath('//p[@class="boldFont blackText airlineName"]') # flight name
        time.sleep(3)
        for x in new_web:
            self.flight.append(x.text)
        #<p class="fliCode">UK 811</p>
        new_web1=self.driver.find_elements_by_xpath('//p[@class="fliCode"]') # flight id
        for x in new_web1:
            self.flight_id.append(x.text)
        #<p class="flightsLayoverInfo">Non stop</p>
        new_web2=self.driver.find_elements_by_xpath('//p[@class="flightsLayoverInfo"]') # stops
        for x in new_web2:
            self.stops.append(x.text)   
        #<p class="darkText">New Delhi</p>
        new_web3=self.driver.find_elements_by_xpath('//p[@class="darkText"]') # airports
        from_to=[]
        for x in new_web3:
            from_to.append(x.text)  
        self.from_=from_to[::2]
        self.to=from_to[1::2]
        #<p class="blackText fontSize18 blackFont white-space-no-wrap">₹ 30,957</p>
        new_web100=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]') # fare
        for x in new_web100:
            self.fare.append(x.text)        
        return self.flight, self.flight_id,self.stops,self.from_,self.to,from_to, self.fare
    def duration_(self):
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>10:40</span></p>
        #<p class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"><span>15:05</span></p>
        new_web4=self.driver.find_elements_by_xpath('//p[@class="blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"]') # depart & arrive
        at=[]
        for x in new_web4:
            at.append(x.text)  
        self.depart_time=at[::2]
        self.arrival_time=at[1::2]
        #<div class="stop-info flexOne"><p>04<font color="#757575"> h </font>25<font color="#757575"> m </font></p><div><div class="relative fliStopsSep"><p class="fliStopsSepLine" style="border-top: 3px solid rgb(245, 166, 34);"></p><span class="fliStopsDisc"></span></div><p class="flightsLayoverInfo">1 stop via Goa</p></div></div>
        new_web5=self.driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]') # depart & arrive
        at1=[]
        for x in new_web5:
            at1.append(x.text)
        new=[]
        for x in at1:
            new.append(x.split('\n'))
        for x in range(len(new)):
            self.duration.append(new[x][0])    
        return self.depart_time, self.arrival_time, self.duration, at1
    def static_data(self):
        for x in range(len(self.flight)):
            self.trip_type.append('One Way')
            self.depart_date.append('06-26-2022')
            self.return_.append('-')
            self.passenger.append('1 Adult')
            self.class_.append('Business')
            self.fare_type.append('Regular')
            self.booking_date.append('06-25-2022')
        return self.trip_type, self.depart_date, self.return_,self.passenger,self.class_,self.fare_type, self.booking_date
    def frame(self):
        data=pd.DataFrame({'Trip Type':self.trip_type, 'Flight Name':self.flight, 'Flight Id':self.flight_id, 'Stops':self.stops,
                          'Flight From':self.from_, 'Flight To':self.to, 'Fare':self.fare, 'Depart Time':self.depart_time,
                          'Arrival Time':self.arrival_time, 'Duration':self.duration, 'Trip Type':self.trip_type,
                          'Depart_Date':self.depart_date, 'Reurn Date':self.return_, 'Passengers':self.passenger, 'Class':self.class_,
                          'Fare Type':self.fare_type,'Booking Date':self.booking_date})
        data.to_csv('data_2.csv')
        self.data=data
        return data
print('*'*30,'Establishing Connection','*'*30)
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('*'*30,'Connection Established Successfully','*'*30)
web='https://www.makemytrip.com/'
def main():
    flight_=[]
    sel=selenium_scrape(driver,web,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    sel.connection()
    conn_sea=sel.web_search()
    flights=sel.name()
    print(flights)
    flights1=sel.duration_()
    print(flights1)
    flights2=sel.static_data()
    print(flights2)
    final_frame=sel.frame()
if __name__=='__main__':
    main()
# Out:
# ====== WebDriver manager ======
# ****************************** Establishing Connection ******************************
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# ****************************** Connection Established Successfully ******************************
# ...

# %%
import pandas as pd
lst=[]
data=pd.read_csv('data.csv')
lst.append(data)
lst
# Out:
# [    Unnamed: 0 Trip Type             Flight Name         Flight Id  \
#  0            0   One Way                  IndiGo           6E 5036
#  1            1   One Way                  IndiGo           6E 2048
#  2            2   One Way                Go First            G8 113
#  3            3   One Way                  IndiGo           6E 6612
#  4            4   One Way                SpiceJet            SG 191
#  5            5   One Way                  IndiGo           6E 2532
#  6            6   One Way                Go First            G8 119
#  7            7   One Way                  IndiGo           6E 2131
#  8            8   One Way                 AirAsia           I5 1732
#  9            9   One Way                  IndiGo           6E 6565
#  10          10   One Way                Go First   G8 2501, G8 317
#  11          11   One Way                SpiceJet            SG 537
#  12          12   One Way                 AirAsia            I5 721
# ...

# %%
for x in range(1,42):
    data=pd.read_csv('data_{}.csv'.format(x))
    lst.append(data)
len(lst)
# Out:
# 42

# %%
for x in range(42):
    print('lst[{}]'.format(x), end=',')
# Out:
# lst[0],lst[1],lst[2],lst[3],lst[4],lst[5],lst[6],lst[7],lst[8],lst[9],lst[10],lst[11],lst[12],lst[13],lst[14],lst[15],lst[16],lst[17],lst[18],lst[19],lst[20],lst[21],lst[22],lst[23],lst[24],lst[25],lst[26],lst[27],lst[28],lst[29],lst[30],lst[31],lst[32],lst[33],lst[34],lst[35],lst[36],lst[37],lst[38],lst[39],lst[40],lst[41],

# %%
flights_data=pd.concat([lst[0],lst[1],lst[2],lst[3],lst[4],lst[5],lst[6],lst[7],lst[8],lst[9],lst[10],lst[11],lst[12],lst[13],lst[14],lst[15],lst[16],lst[17],lst[18],lst[19],lst[20],lst[21],lst[22],lst[23],lst[24],lst[25],lst[26],lst[27],lst[28],lst[29],lst[30],lst[31],lst[32],lst[33],lst[34],lst[35],lst[36],lst[37],lst[38],lst[39],lst[40],lst[41]])
flights_data
# Out:
#     Unnamed: 0 Trip Type            Flight Name       Flight Id  \
# 0            0   One Way                 IndiGo         6E 5036
# 1            1   One Way                 IndiGo         6E 2048
# 2            2   One Way               Go First          G8 113
# 3            3   One Way                 IndiGo         6E 6612
# 4            4   One Way               SpiceJet          SG 191
# ..         ...       ...                    ...             ...
# 37          37   One Way              Air India          AI 502
# 38          38   One Way  Vistara, Alliance Air  UK 899, 9I 518
# 39          39   One Way                Vistara          UK 813
# 40          40   One Way                Vistara          UK 819
# 41          41   One Way                Vistara          UK 817
#
#                    Stops Flight From  Flight To      Fare Depart Time  \
# 0               Non stop   New Delhi  Bengaluru   ₹ 9,419       02:25
# ...

# %%
flights_data.to_csv('flights_data.csv')
